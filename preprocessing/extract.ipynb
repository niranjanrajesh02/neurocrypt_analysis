# %%
import pandas as pd
import os
import json

# %%
# open json file as dictionary
firebase_data_path = '../data/neurocrypt-rtdb-export.json'
with open(firebase_data_path) as f:
    firebase_data = json.load(f)

# %% [markdown]
# ### Data structure
# ```firebase_data``` contains the collected data stored in firebase. The dictionary is structured like this.
#
# The first level key-value pairs are the user_id's and the corresponding user data respectively.
#
# - ```firebase_data[user_id]```
#   - session_id_1 (another dict)
#     - block (a list of dictionaries for each sub-block)
#       - gameNumber (subBlock number)
#       - noiseMetrics (dict with performance on noise)
#         - hitRate
#         - hits
#         - misses
#       - passMetrics (dict with performance on pass-sequence)
#       - subBlockMetrics (dict with performance on entire subBlock)
#     - hitRate (hitrate during entire session)
#     - hits
#     - misses
#     - session (one of "TRAIN", "AUTH1", "AUTH2")
#   - session_id_2
#   - session_id_3
#   - GAMETYPE (one of "VIS", "AUD", "CONTROL")
#   - noteGenerateLag
#   - noteSpeed
# - ... other users

# %%
firebase_data
# Out:
# {'0AT3q4mTMncZcXXdMv8pkQIXdqk1': {'-NvudMOZ3lNhqry-7uON': {'block': [{'gameNumber': 1,
#      'noiseMetrics': {'hitRate': 0.6111111111111112, 'hits': 55, 'misses': 35},
#      'passMetrics': {'hitRate': 0.6488888888888888,
#       'hits': 292,
#       'misses': 158},
#      'subBlockMetrics': {'hitRate': 0.6425925925925926,
#       'hits': 347,
#       'misses': 193}},
#     {'gameNumber': 2,
#      'noiseMetrics': {'hitRate': 0.7888888888888889, 'hits': 71, 'misses': 19},
#      'passMetrics': {'hitRate': 0.7666666666666667,
#       'hits': 345,
#       'misses': 105},
#      'subBlockMetrics': {'hitRate': 0.7703703703703704,
#       'hits': 416,
#       'misses': 124}},
#     {'gameNumber': 3,
#      'noiseMetrics': {'hitRate': 0.6111111111111112, 'hits': 55, 'misses': 35},
#      'passMetrics': {'hitRate': 0.7266666666666667,
#       'hits': 327,
#       'misses': 123},
#      'subBlockMetrics': {'hitRate': 0.7074074074074074,
#       'hits': 382,
#       'misses': 158}},
#     {'gameNumber': 4,
#      'noiseMetrics': {'hitRate': 0.7555555555555555, 'hits': 68, 'misses': 22},
#      'passMetrics': {'hitRate': 0.7177777777777777,
#       'hits': 323,
#       'misses': 127},
#      'subBlockMetrics': {'hitRate': 0.7240740740740741,
#       'hits': 391,
#       'misses': 149}},
#     {'gameNumber': 5,
#      'noiseMetrics': {'hitRate': 0.5555555555555556, 'hits': 50, 'misses': 40},
#      'passMetrics': {'hitRate': 0.6244444444444445,
#       'hits': 281,
#       'misses': 169},
#      'subBlockMetrics': {'hitRate': 0.6129629629629629,
#       'hits': 331,
#       'misses': 209}},
#     {'gameNumber': 6,
#      'noiseMetrics': {'hitRate': 0.7555555555555555, 'hits': 68, 'misses': 22},
#      'passMetrics': {'hitRate': 0.7733333333333333,
#       'hits': 348,
#       'misses': 102},
#      'subBlockMetrics': {'hitRate': 0.7703703703703704,
#       'hits': 416,
#       'misses': 124}},
#     {'gameNumber': 7,
#      'noiseMetrics': {'hitRate': 0.7555555555555555, 'hits': 68, 'misses': 22},
#      'passMetrics': {'hitRate': 0.86, 'hits': 387, 'misses': 63},
#      'subBlockMetrics': {'hitRate': 0.8425925925925926,
#       'hits': 455,
#       'misses': 85}}],
#    'hitRate': 0.7243386243386244,
#    'hits': 2738,
#    'misses': 1042,
#    'session': 'TRAIN'},
#   'GAMETYPE': 'CONTROL',
#   'noteGenerateLag': 20,
#   'noteSpeed': 3,
#   'passSeq': ['D',
#    'K',
#    'J',
#    'D',
#    'F',
#    'D',
#    'L',
#    'K',
#    'S',
#    'K',
#    'D',
#    'J',
#    'S',
#    'F',
#    'K',
#    'F',
#    'F',
#    'L',
#    'F',
#    'J',
#    'L',
#    'D',
#    'J',
#    'K',
#    'L',
#    'J',
#    'S',
#    'L',
#    'S',
#    'D']},
#  '267spXKQrOQxNGhW9Mj19RVBZnF3': {'-NvqocgsYbxRVJ34EPZA': {'block': [{'gameNumber': 1,
#      'noiseMetrics': {'hitRate': 0.7444444444444445, 'hits': 67, 'misses': 23},
#      'passMetrics': {'hitRate': 0.7133333333333334,
#       'hits': 321,
#       'misses': 129},
#      'subBlockMetrics': {'hitRate': 0.7185185185185186,
#       'hits': 388,
#       'misses': 152}},
#     {'gameNumber': 2,
#      'noiseMetrics': {'hitRate': 0.6333333333333333, 'hits': 57, 'misses': 33},
#      'passMetrics': {'hitRate': 0.6, 'hits': 270, 'misses': 180},
#      'subBlockMetrics': {'hitRate': 0.6055555555555555,
#       'hits': 327,
#       'misses': 213}},
#     {'gameNumber': 3,
#      'noiseMetrics': {'hitRate': 0.7888888888888889, 'hits': 71, 'misses': 19},
#      'passMetrics': {'hitRate': 0.6577777777777778,
#       'hits': 296,
#       'misses': 154},
#      'subBlockMetrics': {'hitRate': 0.6796296296296296,
#       'hits': 367,
#       'misses': 173}},
#     {'gameNumber': 4,
#      'noiseMetrics': {'hitRate': 0.7777777777777778, 'hits': 70, 'misses': 20},
#      'passMetrics': {'hitRate': 0.7644444444444445,
#       'hits': 344,
#       'misses': 106},
#      'subBlockMetrics': {'hitRate': 0.7666666666666667,
#       'hits': 414,
#       'misses': 126}},
#     {'gameNumber': 5,
#      'noiseMetrics': {'hitRate': 0.7333333333333333, 'hits': 66, 'misses': 24},
#      'passMetrics': {'hitRate': 0.66, 'hits': 297, 'misses': 153},
#      'subBlockMetrics': {'hitRate': 0.6722222222222223,
#       'hits': 363,
#       'misses': 177}},
#     {'gameNumber': 6,
#      'noiseMetrics': {'hitRate': 0.6444444444444445, 'hits': 58, 'misses': 32},
#      'passMetrics': {'hitRate': 0.6711111111111111,
#       'hits': 302,
#       'misses': 148},
#      'subBlockMetrics': {'hitRate': 0.6666666666666666,
#       'hits': 360,
#       'misses': 180}},
#     {'gameNumber': 7,
#      'noiseMetrics': {'hitRate': 0.6777777777777778, 'hits': 61, 'misses': 29},
#      'passMetrics': {'hitRate': 0.68, 'hits': 306, 'misses': 144},
#      'subBlockMetrics': {'hitRate': 0.6796296296296296,
#       'hits': 367,
#       'misses': 173}}],
#    'hitRate': 0.6841269841269841,
#    'hits': 2586,
#    'misses': 1194,
#    'session': 'TRAIN'},
#   '-NwPU5YJbs8a2IoMIKbH': {'block': [{'gameNumber': 1,
#      'noiseMetrics': {'hitRate': 0.6472222222222223,
#       'hits': 233,
#       'misses': 127},
#      'passMetrics': {'hitRate': 0.7833333333333333, 'hits': 141, 'misses': 39},
#      'subBlockMetrics': {'hitRate': 0.6925925925925925,
#       'hits': 374,
#       'misses': 166}}],
#    'hitRate': 0.6925925925925925,
#    'hits': 374,
#    'misses': 166,
#    'session': 'AUTH1'},
#   '-NwydfxiR-XvIVvIR_qD': {'block': [{'gameNumber': 1,
#      'noiseMetrics': {'hitRate': 0.6888888888888889,
#       'hits': 248,
#       'misses': 112},
#      'passMetrics': {'hitRate': 0.7277777777777777, 'hits': 131, 'misses': 49},
#      'subBlockMetrics': {'hitRate': 0.7018518518518518,
#       'hits': 379,
#       'misses': 161}}],
#    'hitRate': 0.7018518518518518,
#    'hits': 379,
#    'misses': 161,
#    'session': 'AUTH2'},
#   'GAMETYPE': 'AUD',
#   'noteGenerateLag': 20,
#   'noteSpeed': 5,
#   'passSeq': ['D',
#    'K',
#    'J',
#    'D',
#    'F',
#    'D',
#    'L',
#    'K',
#    'S',
#    'K',
#    'D',
#    'J',
#    'S',
#    'F',
#    'K',
#    'F',
#    'F',
#    'L',
#    'F',
#    'J',
#    'L',
#    'D',
#    'J',
#    'K',
#    'L',
#    'J',
#    'S',
#    'L',
#    'S',
#    'D']},
#  '2IuHuexDUpgOdXCBYfDqO7ubtEC2': {'-Nvqqq-pCpN4ZdnIXA4p': {'block': [{'gameNumber': 1,
#      'noiseMetrics': {'hitRate': 0.5222222222222223, 'hits': 47, 'misses': 43},
#      'passMetrics': {'hitRate': 0.7244444444444444,
#       'hits': 326,
#       'misses': 124},
#      'subBlockMetrics': {'hitRate': 0.6907407407407408,
#       'hits': 373,
#       'misses': 167}},
#     {'gameNumber': 2,
#      'noiseMetrics': {'hitRate': 0.8111111111111111, 'hits': 73, 'misses': 17},
#      'passMetrics': {'hitRate': 0.8933333333333333, 'hits': 402, 'misses': 48},
#      'subBlockMetrics': {'hitRate': 0.8796296296296297,
#       'hits': 475,
#       'misses': 65}},
#     {'gameNumber': 3,
#      'noiseMetrics': {'hitRate': 0.7, 'hits': 63, 'misses': 27},
#      'passMetrics': {'hitRate': 0.8266666666666667, 'hits': 372, 'misses': 78},
#      'subBlockMetrics': {'hitRate': 0.8055555555555556,
#       'hits': 435,
#       'misses': 105}},
#     {'gameNumber': 4,
#      'noiseMetrics': {'hitRate': 0.6666666666666666, 'hits': 60, 'misses': 30},
#      'passMetrics': {'hitRate': 0.7688888888888888,
#       'hits': 346,
#       'misses': 104},
#      'subBlockMetrics': {'hitRate': 0.7518518518518519,
#       'hits': 406,
#       'misses': 134}},
#     {'gameNumber': 5,
#      'noiseMetrics': {'hitRate': 0.8555555555555555, 'hits': 77, 'misses': 13},
#      'passMetrics': {'hitRate': 0.8355555555555556, 'hits': 376, 'misses': 74},
#      'subBlockMetrics': {'hitRate': 0.8388888888888889,
#       'hits': 453,
#       'misses': 87}},
#     {'gameNumber': 6,
#      'noiseMetrics': {'hitRate': 0.7777777777777778, 'hits': 70, 'misses': 20},
#      'passMetrics': {'hitRate': 0.7866666666666666, 'hits': 354, 'misses': 96},
#      'subBlockMetrics': {'hitRate': 0.7851851851851852,
#       'hits': 424,
#       'misses': 116}},
#     {'gameNumber': 7,
#      'noiseMetrics': {'hitRate': 0.8444444444444444, 'hits': 76, 'misses': 14},
#      'passMetrics': {'hitRate': 0.8711111111111111, 'hits': 392, 'misses': 58},
#      'subBlockMetrics': {'hitRate': 0.8666666666666667,
#       'hits': 468,
#       'misses': 72}}],
#    'hitRate': 0.8026455026455026,
#    'hits': 3034,
#    'misses': 746,
#    'session': 'TRAIN'},
#   '-NwQ-YqMwJDdQmIihgea': {'block': [{'gameNumber': 1,
#      'noiseMetrics': {'hitRate': 0.5861111111111111,
#       'hits': 211,
#       'misses': 149},
#      'passMetrics': {'hitRate': 0.7888888888888889, 'hits': 142, 'misses': 38},
#      'subBlockMetrics': {'hitRate': 0.6537037037037037,
#       'hits': 353,
#       'misses': 187}}],
#    'hitRate': 0.6537037037037037,
#    'hits': 353,
#    'misses': 187,
#    'session': 'AUTH1'},
#   '-Nwz2Y9_ESe21jYHVxko': {'block': [{'gameNumber': 1,
#      'noiseMetrics': {'hitRate': 0.6666666666666666,
#       'hits': 240,
#       'misses': 120},
#      'passMetrics': {'hitRate': 0.85, 'hits': 153, 'misses': 27},
#      'subBlockMetrics': {'hitRate': 0.7277777777777777,
#       'hits': 393,
#       'misses': 147}}],
#    'hitRate': 0.7277777777777777,
#    'hits': 393,
#    'misses': 147,
#    'session': 'AUTH2'},
#   'GAMETYPE': 'AUD',
#   'noteGenerateLag': 20,
#   'noteSpeed': 9,
#   'passSeq': ['S',
#    'L',
#    'L',
#    'J',
#    'J',
#    'L',
#    'L',
#    'D',
#    'D',
#    'K',
#    'L',
#    'K',
#    'S',
#    'K',
#    'S',
#    'J',
#    'D',
#    'J',
#    'K',
#    'J',
#    'K',
#    'F',
#    'F',
#    'K',
#    'S',
#    'F',
#    'D',
#    'L',
#    'L',
#    'F']},
#  '3YKJchZqXXPUm7ouoYwzWlTp4D53': {'-Nw50CL3_b6f-ThcAeD3': {'block': [{'gameNumber': 1,
#      'noiseMetrics': {'hitRate': 0.6444444444444445, 'hits': 58, 'misses': 32},
#      'passMetrics': {'hitRate': 0.7511111111111111,
#       'hits': 338,
#       'misses': 112},
#      'subBlockMetrics': {'hitRate': 0.7333333333333333,
#       'hits': 396,
#       'misses': 144}},
#     {'gameNumber': 2,
#      'noiseMetrics': {'hitRate': 0.5666666666666667, 'hits': 51, 'misses': 39},
#      'passMetrics': {'hitRate': 0.6866666666666666,
#       'hits': 309,
#       'misses': 141},
#      'subBlockMetrics': {'hitRate': 0.6666666666666666,
#       'hits': 360,
#       'misses': 180}},
#     {'gameNumber': 3,
#      'noiseMetrics': {'hitRate': 0.4888888888888889, 'hits': 44, 'misses': 46},
#      'passMetrics': {'hitRate': 0.6333333333333333,
#       'hits': 285,
#       'misses': 165},
#      'subBlockMetrics': {'hitRate': 0.6092592592592593,
#       'hits': 329,
#       'misses': 211}},
#     {'gameNumber': 4,
#      'noiseMetrics': {'hitRate': 0.7444444444444445, 'hits': 67, 'misses': 23},
#      'passMetrics': {'hitRate': 0.8377777777777777, 'hits': 377, 'misses': 73},
#      'subBlockMetrics': {'hitRate': 0.8222222222222222,
#       'hits': 444,
#       'misses': 96}},
#     {'gameNumber': 5,
#      'noiseMetrics': {'hitRate': 0.5, 'hits': 45, 'misses': 45},
#      'passMetrics': {'hitRate': 0.5066666666666667,
#       'hits': 228,
#       'misses': 222},
#      'subBlockMetrics': {'hitRate': 0.5055555555555555,
#       'hits': 273,
#       'misses': 267}},
#     {'gameNumber': 6,
#      'noiseMetrics': {'hitRate': 0.5777777777777777, 'hits': 52, 'misses': 38},
#      'passMetrics': {'hitRate': 0.6466666666666666,
#       'hits': 291,
#       'misses': 159},
#      'subBlockMetrics': {'hitRate': 0.6351851851851852,
#       'hits': 343,
#       'misses': 197}},
#     {'gameNumber': 7,
#      'noiseMetrics': {'hitRate': 0.8111111111111111, 'hits': 73, 'misses': 17},
#      'passMetrics': {'hitRate': 0.7622222222222222,
#       'hits': 343,
#       'misses': 107},
#      'subBlockMetrics': {'hitRate': 0.7703703703703704,
#       'hits': 416,
#       'misses': 124}}],
#    'hitRate': 0.6775132275132275,
#    'hits': 2561,
#    'misses': 1219,
#    'session': 'TRAIN'},
#   '-NwTsyKGFsihZ2ZC2pjX': {'block': [{'gameNumber': 1,
#      'noiseMetrics': {'hitRate': 0.7388888888888889,
#       'hits': 266,
#       'misses': 94},
#      'passMetrics': {'hitRate': 0.6444444444444445, 'hits': 116, 'misses': 64},
#      'subBlockMetrics': {'hitRate': 0.7074074074074074,
#       'hits': 382,
#       'misses': 158}}],
#    'hitRate': 0.7074074074074074,
#    'hits': 382,
#    'misses': 158,
#    'session': 'AUTH1'},
#   '-Nx6r0vdizIc2Ednwugj': {'block': [{'gameNumber': 1,
#      'noiseMetrics': {'hitRate': 0.6777777777777778,
#       'hits': 244,
#       'misses': 116},
#      'passMetrics': {'hitRate': 0.5833333333333334, 'hits': 105, 'misses': 75},
#      'subBlockMetrics': {'hitRate': 0.6462962962962963,
#       'hits': 349,
#       'misses': 191}}],
#    'hitRate': 0.6462962962962963,
#    'hits': 349,
#    'misses': 191,
#    'session': 'AUTH2'},
#   'GAMETYPE': 'CONTROL',
#   'noteGenerateLag': 24,
#   'noteSpeed': 3,
#   'passSeq': ['K',
#    'J',
#    'K',
#    'F',
#    'L',
#    'J',
#    'D',
#    'F',
#    'K',
#    'L',
#    'D',
#    'K',
#    'S',
#    'K',
#    'D',
#    'L',
#    'S',
#    'D',
#    'S',
#    'F',
#    'F',
#    'J',
#    'S',
#    'J',
#    'L',
#    'F',
#    'D',
#    'J',
#    'L',
#    'K']},
#  '4SQKvEIUBucwuWNoKkOVBX30H1P2': {'-NvudhlSvSDm8zXYTuFp': {'block': [{'gameNumber': 1,
#      'noiseMetrics': {'hitRate': 0.7222222222222222, 'hits': 65, 'misses': 25},
#      'passMetrics': {'hitRate': 0.6244444444444445,
#       'hits': 281,
#       'misses': 169},
#      'subBlockMetrics': {'hitRate': 0.6407407407407407,
#       'hits': 346,
#       'misses': 194}},
#     {'gameNumber': 2,
#      'noiseMetrics': {'hitRate': 0.7111111111111111, 'hits': 64, 'misses': 26},
#      'passMetrics': {'hitRate': 0.7888888888888889, 'hits': 355, 'misses': 95},
#      'subBlockMetrics': {'hitRate': 0.7759259259259259,
#       'hits': 419,
#       'misses': 121}},
#     {'gameNumber': 3,
#      'noiseMetrics': {'hitRate': 0.7333333333333333, 'hits': 66, 'misses': 24},
#      'passMetrics': {'hitRate': 0.7288888888888889,
#       'hits': 328,
#       'misses': 122},
#      'subBlockMetrics': {'hitRate': 0.7296296296296296,
#       'hits': 394,
#       'misses': 146}},
#     {'gameNumber': 4,
#      'noiseMetrics': {'hitRate': 0.6777777777777778, 'hits': 61, 'misses': 29},
#      'passMetrics': {'hitRate': 0.7088888888888889,
#       'hits': 319,
#       'misses': 131},
#      'subBlockMetrics': {'hitRate': 0.7037037037037037,
#       'hits': 380,
#       'misses': 160}},
#     {'gameNumber': 5,
#      'noiseMetrics': {'hitRate': 0.6666666666666666, 'hits': 60, 'misses': 30},
#      'passMetrics': {'hitRate': 0.7377777777777778,
#       'hits': 332,
#       'misses': 118},
#      'subBlockMetrics': {'hitRate': 0.725925925925926,
#       'hits': 392,
#       'misses': 148}},
#     {'gameNumber': 6,
#      'noiseMetrics': {'hitRate': 0.6444444444444445, 'hits': 58, 'misses': 32},
#      'passMetrics': {'hitRate': 0.7577777777777778,
#       'hits': 341,
#       'misses': 109},
#      'subBlockMetrics': {'hitRate': 0.7388888888888889,
#       'hits': 399,
#       'misses': 141}},
#     {'gameNumber': 7,
#      'noiseMetrics': {'hitRate': 0.7777777777777778, 'hits': 70, 'misses': 20},
#      'passMetrics': {'hitRate': 0.8288888888888889, 'hits': 373, 'misses': 77},
#      'subBlockMetrics': {'hitRate': 0.8203703703703704,
#       'hits': 443,
#       'misses': 97}}],
#    'hitRate': 0.7335978835978836,
#    'hits': 2773,
#    'misses': 1007,
#    'session': 'TRAIN'},
#   '-NwTk0RSUSIG4L_0S0Fn': {'block': [{'gameNumber': 1,
#      'noiseMetrics': {'hitRate': 0.7166666666666667,
#       'hits': 258,
#       'misses': 102},
#      'passMetrics': {'hitRate': 0.7055555555555556, 'hits': 127, 'misses': 53},
#      'subBlockMetrics': {'hitRate': 0.7129629629629629,
#       'hits': 385,
#       'misses': 155}}],
#    'hitRate': 0.7129629629629629,
#    'hits': 385,
#    'misses': 155,
#    'session': 'AUTH1'},
#   '-Nx2sYOBy--XYQX1o4aC': {'block': [{'gameNumber': 1,
#      'noiseMetrics': {'hitRate': 0.7, 'hits': 252, 'misses': 108},
#      'passMetrics': {'hitRate': 0.7388888888888889, 'hits': 133, 'misses': 47},
#      'subBlockMetrics': {'hitRate': 0.7129629629629629,
#       'hits': 385,
#       'misses': 155}}],
#    'hitRate': 0.7129629629629629,
#    'hits': 385,
#    'misses': 155,
#    'session': 'AUTH2'},
#   'GAMETYPE': 'CONTROL',
#   'noteGenerateLag': 20,
#   'noteSpeed': 6,
#   'passSeq': ['K',
#    'J',
#    'K',
#    'F',
#    'L',
#    'J',
#    'D',
#    'F',
#    'K',
#    'L',
#    'D',
#    'K',
#    'S',
#    'K',
#    'D',
#    'L',
#    'S',
#    'D',
#    'S',
#    'F',
#    'F',
#    'J',
#    'S',
#    'J',
#    'L',
#    'F',
#    'D',
#    'J',
#    'L',
#    'K']},
#  '5NToitXbnhXNNLn80hbxLBUSbfw2': {'-Nw5Ay0SbPQZ2zvVly96': {'block': [{'gameNumber': 1,
#      'noiseMetrics': {'hitRate': 0.7333333333333333, 'hits': 66, 'misses': 24},
#      'passMetrics': {'hitRate': 0.7066666666666667,
#       'hits': 318,
#       'misses': 132},
#      'subBlockMetrics': {'hitRate': 0.7111111111111111,
#       'hits': 384,
#       'misses': 156}},
#     {'gameNumber': 2,
#      'noiseMetrics': {'hitRate': 0.8333333333333334, 'hits': 75, 'misses': 15},
#      'passMetrics': {'hitRate': 0.7933333333333333, 'hits': 357, 'misses': 93},
#      'subBlockMetrics': {'hitRate': 0.8, 'hits': 432, 'misses': 108}},
#     {'gameNumber': 3,
#      'noiseMetrics': {'hitRate': 0.7555555555555555, 'hits': 68, 'misses': 22},
#      'passMetrics': {'hitRate': 0.8377777777777777, 'hits': 377, 'misses': 73},
#      'subBlockMetrics': {'hitRate': 0.8240740740740741,
#       'hits': 445,
#       'misses': 95}},
#     {'gameNumber': 4,
#      'noiseMetrics': {'hitRate': 0.9111111111111111, 'hits': 82, 'misses': 8},
#      'passMetrics': {'hitRate': 0.8311111111111111, 'hits': 374, 'misses': 76},
#      'subBlockMetrics': {'hitRate': 0.8444444444444444,
#       'hits': 456,
#       'misses': 84}},
#     {'gameNumber': 5,
#      'noiseMetrics': {'hitRate': 0.6777777777777778, 'hits': 61, 'misses': 29},
#      'passMetrics': {'hitRate': 0.8488888888888889, 'hits': 382, 'misses': 68},
#      'subBlockMetrics': {'hitRate': 0.8203703703703704,
#       'hits': 443,
#       'misses': 97}},
#     {'gameNumber': 6,
#      'noiseMetrics': {'hitRate': 0.6777777777777778, 'hits': 61, 'misses': 29},
#      'passMetrics': {'hitRate': 0.7955555555555556, 'hits': 358, 'misses': 92},
#      'subBlockMetrics': {'hitRate': 0.7759259259259259,
#       'hits': 419,
#       'misses': 121}},
#     {'gameNumber': 7,
#      'noiseMetrics': {'hitRate': 0.5666666666666667, 'hits': 51, 'misses': 39},
#      'passMetrics': {'hitRate': 0.7666666666666667,
#       'hits': 345,
#       'misses': 105},
#      'subBlockMetrics': {'hitRate': 0.7333333333333333,
#       'hits': 396,
#       'misses': 144}}],
#    'hitRate': 0.7870370370370371,
#    'hits': 2975,
#    'misses': 805,
#    'session': 'TRAIN'},
#   '-Nw_AmLzguW8wZQ6-EAn': {'block': [{'gameNumber': 1,
#      'noiseMetrics': {'hitRate': 0.6944444444444444,
#       'hits': 250,
#       'misses': 110},
#      'passMetrics': {'hitRate': 0.8055555555555556, 'hits': 145, 'misses': 35},
#      'subBlockMetrics': {'hitRate': 0.7314814814814815,
#       'hits': 395,
#       'misses': 145}}],
#    'hitRate': 0.7314814814814815,
#    'hits': 395,
#    'misses': 145,
#    'session': 'AUTH1'},
#   '-Nx8CnDHbpvQNlsRx7CD': {'block': [{'gameNumber': 1,
#      'noiseMetrics': {'hitRate': 0.7166666666666667,
#       'hits': 258,
#       'misses': 102},
#      'passMetrics': {'hitRate': 0.8, 'hits': 144, 'misses': 36},
#      'subBlockMetrics': {'hitRate': 0.7444444444444445,
#       'hits': 402,
#       'misses': 138}}],
#    'hitRate': 0.7444444444444445,
#    'hits': 402,
#    'misses': 138,
#    'session': 'AUTH2'},
#   'GAMETYPE': 'VIS',
#   'noteGenerateLag': 20,
#   'noteSpeed': 12,
#   'passSeq': ['S',
#    'L',
#    'L',
#    'J',
#    'J',
#    'L',
#    'L',
#    'D',
#    'D',
#    'K',
#    'L',
#    'K',
#    'S',
#    'K',
#    'S',
#    'J',
#    'D',
#    'J',
#    'K',
#    'J',
#    'K',
#    'F',
#    'F',
#    'K',
#    'S',
#    'F',
#    'D',
#    'L',
#    'L',
#    'F']},
#  '61Alts16Drd976ojNN40qLI0OYf2': {'-NvqmnazG86yuDUyz5YD': {'block': [{'gameNumber': 1,
#      'noiseMetrics': {'hitRate': 0.6, 'hits': 54, 'misses': 36},
#      'passMetrics': {'hitRate': 0.6844444444444444,
#       'hits': 308,
#       'misses': 142},
#      'subBlockMetrics': {'hitRate': 0.6703703703703704,
#       'hits': 362,
#       'misses': 178}},
#     {'gameNumber': 2,
#      'noiseMetrics': {'hitRate': 0.8, 'hits': 72, 'misses': 18},
#      'passMetrics': {'hitRate': 0.7622222222222222,
#       'hits': 343,
#       'misses': 107},
#      'subBlockMetrics': {'hitRate': 0.7685185185185185,
#       'hits': 415,
#       'misses': 125}},
#     {'gameNumber': 3,
#      'noiseMetrics': {'hitRate': 0.6777777777777778, 'hits': 61, 'misses': 29},
#      'passMetrics': {'hitRate': 0.7555555555555555,
#       'hits': 340,
#       'misses': 110},
#      'subBlockMetrics': {'hitRate': 0.7425925925925926,
#       'hits': 401,
#       'misses': 139}},
#     {'gameNumber': 4,
#      'noiseMetrics': {'hitRate': 0.5222222222222223, 'hits': 47, 'misses': 43},
#      'passMetrics': {'hitRate': 0.6311111111111111,
#       'hits': 284,
#       'misses': 166},
#      'subBlockMetrics': {'hitRate': 0.6129629629629629,
#       'hits': 331,
#       'misses': 209}},
#     {'gameNumber': 5,
#      'noiseMetrics': {'hitRate': 0.5666666666666667, 'hits': 51, 'misses': 39},
#      'passMetrics': {'hitRate': 0.7066666666666667,
#       'hits': 318,
#       'misses': 132},
#      'subBlockMetrics': {'hitRate': 0.6833333333333333,
#       'hits': 369,
#       'misses': 171}},
#     {'gameNumber': 6,
#      'noiseMetrics': {'hitRate': 0.6222222222222222, 'hits': 56, 'misses': 34},
#      'passMetrics': {'hitRate': 0.7355555555555555,
#       'hits': 331,
#       'misses': 119},
#      'subBlockMetrics': {'hitRate': 0.7166666666666667,
#       'hits': 387,
#       'misses': 153}},
#     {'gameNumber': 7,
#      'noiseMetrics': {'hitRate': 0.5888888888888889, 'hits': 53, 'misses': 37},
#      'passMetrics': {'hitRate': 0.7755555555555556,
#       'hits': 349,
#       'misses': 101},
#      'subBlockMetrics': {'hitRate': 0.7444444444444445,
#       'hits': 402,
#       'misses': 138}}],
#    'hitRate': 0.7055555555555556,
#    'hits': 2667,
#    'misses': 1113,
#    'session': 'TRAIN'},
#   'GAMETYPE': 'AUD',
#   'noteGenerateLag': 20,
#   'noteSpeed': 3,
#   'passSeq': ['K',
#    'J',
#    'K',
#    'F',
#    'L',
#    'J',
#    'D',
#    'F',
#    'K',
#    'L',
#    'D',
#    'K',
#    'S',
#    'K',
#    'D',
#    'L',
#    'S',
#    'D',
#    'S',
#    'F',
#    'F',
#    'J',
#    'S',
#    'J',
#    'L',
#    'F',
#    'D',
#    'J',
#    'L',
#    'K']},
#  '65qKvHVigZWSKEudna7mKuXpDVP2': {'-Nw0IRLIrKgqghd5ObCf': {'block': [{'gameNumber': 1,
#      'noiseMetrics': {'hitRate': 0.7444444444444445, 'hits': 67, 'misses': 23},
#      'passMetrics': {'hitRate': 0.8355555555555556, 'hits': 376, 'misses': 74},
#      'subBlockMetrics': {'hitRate': 0.8203703703703704,
#       'hits': 443,
#       'misses': 97}},
#     {'gameNumber': 2,
#      'noiseMetrics': {'hitRate': 0.9222222222222223, 'hits': 83, 'misses': 7},
#      'passMetrics': {'hitRate': 0.8644444444444445, 'hits': 389, 'misses': 61},
#      'subBlockMetrics': {'hitRate': 0.8740740740740741,
#       'hits': 472,
#       'misses': 68}},
#     {'gameNumber': 3,
#      'noiseMetrics': {'hitRate': 0.8444444444444444, 'hits': 76, 'misses': 14},
#      'passMetrics': {'hitRate': 0.9111111111111111, 'hits': 410, 'misses': 40},
#      'subBlockMetrics': {'hitRate': 0.9, 'hits': 486, 'misses': 54}},
#     {'gameNumber': 4,
#      'noiseMetrics': {'hitRate': 0.7888888888888889, 'hits': 71, 'misses': 19},
#      'passMetrics': {'hitRate': 0.8911111111111111, 'hits': 401, 'misses': 49},
#      'subBlockMetrics': {'hitRate': 0.8740740740740741,
#       'hits': 472,
#       'misses': 68}},
#     {'gameNumber': 5,
#      'noiseMetrics': {'hitRate': 0.8333333333333334, 'hits': 75, 'misses': 15},
#      'passMetrics': {'hitRate': 0.8911111111111111, 'hits': 401, 'misses': 49},
#      'subBlockMetrics': {'hitRate': 0.8814814814814815,
#       'hits': 476,
#       'misses': 64}},
#     {'gameNumber': 6,
#      'noiseMetrics': {'hitRate': 0.8444444444444444, 'hits': 76, 'misses': 14},
#      'passMetrics': {'hitRate': 0.9288888888888889, 'hits': 418, 'misses': 32},
#      'subBlockMetrics': {'hitRate': 0.9148148148148149,
#       'hits': 494,
#       'misses': 46}},
#     {'gameNumber': 7,
#      'noiseMetrics': {'hitRate': 0.8444444444444444, 'hits': 76, 'misses': 14},
#      'passMetrics': {'hitRate': 0.9022222222222223, 'hits': 406, 'misses': 44},
#      'subBlockMetrics': {'hitRate': 0.8925925925925926,
#       'hits': 482,
#       'misses': 58}}],
#    'hitRate': 0.8796296296296297,
#    'hits': 3325,
#    'misses': 455,
#    'session': 'TRAIN'},
#   '-NwTT9tJWrzkykpx5-UR': {'block': [{'gameNumber': 1,
#      'noiseMetrics': {'hitRate': 0.8305555555555556,
#       'hits': 299,
#       'misses': 61},
#      'passMetrics': {'hitRate': 0.8111111111111111, 'hits': 146, 'misses': 34},
#      'subBlockMetrics': {'hitRate': 0.8240740740740741,
#       'hits': 445,
#       'misses': 95}}],
#    'hitRate': 0.8240740740740741,
#    'hits': 445,
#    'misses': 95,
#    'session': 'AUTH1'},
#   '-Nx36vAOpB_ztHY7Oxk9': {'block': [{'gameNumber': 1,
#      'noiseMetrics': {'hitRate': 0.9611111111111111,
#       'hits': 346,
#       'misses': 14},
#      'passMetrics': {'hitRate': 0.9777777777777777, 'hits': 176, 'misses': 4},
#      'subBlockMetrics': {'hitRate': 0.9666666666666667,
#       'hits': 522,
#       'misses': 18}}],
#    'hitRate': 0.9666666666666667,
#    'hits': 522,
#    'misses': 18,
#    'session': 'AUTH2'},
#   'GAMETYPE': 'CONTROL',
#   'noteGenerateLag': 20,
#   'noteSpeed': 12,
#   'passSeq': ['D',
#    'K',
#    'J',
#    'D',
#    'F',
#    'D',
#    'L',
#    'K',
#    'S',
#    'K',
#    'D',
#    'J',
#    'S',
#    'F',
#    'K',
#    'F',
#    'F',
#    'L',
#    'F',
#    'J',
#    'L',
#    'D',
#    'J',
#    'K',
#    'L',
#    'J',
#    'S',
#    'L',
#    'S',
#    'D']},
#  '6VsFHBaB5TQR0W75K7JqBffETTF2': {'-NwGFIBFfHv4H_zHdX_X': {'block': [{'gameNumber': 1,
#      'noiseMetrics': {'hitRate': 0.6111111111111112, 'hits': 55, 'misses': 35},
#      'passMetrics': {'hitRate': 0.6733333333333333,
#       'hits': 303,
#       'misses': 147},
#      'subBlockMetrics': {'hitRate': 0.662962962962963,
#       'hits': 358,
#       'misses': 182}},
#     {'gameNumber': 2,
#      'noiseMetrics': {'hitRate': 0.6444444444444445, 'hits': 58, 'misses': 32},
#      'passMetrics': {'hitRate': 0.7333333333333333,
#       'hits': 330,
#       'misses': 120},
#      'subBlockMetrics': {'hitRate': 0.7185185185185186,
#       'hits': 388,
#       'misses': 152}},
#     {'gameNumber': 3,
#      'noiseMetrics': {'hitRate': 0.6222222222222222, 'hits': 56, 'misses': 34},
#      'passMetrics': {'hitRate': 0.7933333333333333, 'hits': 357, 'misses': 93},
#      'subBlockMetrics': {'hitRate': 0.7648148148148148,
#       'hits': 413,
#       'misses': 127}},
#     {'gameNumber': 4,
#      'noiseMetrics': {'hitRate': 0.5222222222222223, 'hits': 47, 'misses': 43},
#      'passMetrics': {'hitRate': 0.7133333333333334,
#       'hits': 321,
#       'misses': 129},
#      'subBlockMetrics': {'hitRate': 0.6814814814814815,
#       'hits': 368,
#       'misses': 172}},
#     {'gameNumber': 5,
#      'noiseMetrics': {'hitRate': 0.6555555555555556, 'hits': 59, 'misses': 31},
#      'passMetrics': {'hitRate': 0.7555555555555555,
#       'hits': 340,
#       'misses': 110},
#      'subBlockMetrics': {'hitRate': 0.7388888888888889,
#       'hits': 399,
#       'misses': 141}},
#     {'gameNumber': 6,
#      'noiseMetrics': {'hitRate': 0.5888888888888889, 'hits': 53, 'misses': 37},
#      'passMetrics': {'hitRate': 0.7533333333333333,
#       'hits': 339,
#       'misses': 111},
#      'subBlockMetrics': {'hitRate': 0.725925925925926,
#       'hits': 392,
#       'misses': 148}},
#     {'gameNumber': 7,
#      'noiseMetrics': {'hitRate': 0.5777777777777777, 'hits': 52, 'misses': 38},
#      'passMetrics': {'hitRate': 0.72, 'hits': 324, 'misses': 126},
#      'subBlockMetrics': {'hitRate': 0.6962962962962963,
#       'hits': 376,
#       'misses': 164}}],
#    'hitRate': 0.7126984126984127,
#    'hits': 2694,
#    'misses': 1086,
#    'session': 'TRAIN'},
#   '-Nw_BkdOuxTFaqf0pjj1': {'block': [{'gameNumber': 1,
#      'noiseMetrics': {'hitRate': 0.6472222222222223,
#       'hits': 233,
#       'misses': 127},
#      'passMetrics': {'hitRate': 0.7944444444444444, 'hits': 143, 'misses': 37},
#      'subBlockMetrics': {'hitRate': 0.6962962962962963,
#       'hits': 376,
#       'misses': 164}}],
#    'hitRate': 0.6962962962962963,
#    'hits': 376,
#    'misses': 164,
#    'session': 'AUTH1'},
#   '-Nx8--Xr3RlawmX700cN': {'block': [{'gameNumber': 1,
#      'noiseMetrics': {'hitRate': 0.5972222222222222,
#       'hits': 215,
#       'misses': 145},
#      'passMetrics': {'hitRate': 0.8222222222222222, 'hits': 148, 'misses': 32},
#      'subBlockMetrics': {'hitRate': 0.6722222222222223,
#       'hits': 363,
#       'misses': 177}}],
#    'hitRate': 0.6722222222222223,
#    'hits': 363,
#    'misses': 177,
#    'session': 'AUTH2'},
#   'GAMETYPE': 'VIS',
#   'noteGenerateLag': 20,
#   'noteSpeed': 3,
#   'passSeq': ['S',
#    'L',
#    'L',
#    'J',
#    'J',
#    'L',
#    'L',
#    'D',
#    'D',
#    'K',
#    'L',
#    'K',
#    'S',
#    'K',
#    'S',
#    'J',
#    'D',
#    'J',
#    'K',
#    'J',
#    'K',
#    'F',
#    'F',
#    'K',
#    'S',
#    'F',
#    'D',
#    'L',
#    'L',
#    'F']},
#  '9FfHMesEQPaqyAYWwWe1SHcOkTc2': {'-NvqsIkkACXqm_PXdMif': {'block': [{'gameNumber': 1,
#      'noiseMetrics': {'hitRate': 0.8555555555555555, 'hits': 77, 'misses': 13},
#      'passMetrics': {'hitRate': 0.7911111111111111, 'hits': 356, 'misses': 94},
#      'subBlockMetrics': {'hitRate': 0.8018518518518518,
#       'hits': 433,
#       'misses': 107}},
#     {'gameNumber': 2,
#      'noiseMetrics': {'hitRate': 0.5777777777777777, 'hits': 52, 'misses': 38},
#      'passMetrics': {'hitRate': 0.5466666666666666,
#       'hits': 246,
#       'misses': 204},
#      'subBlockMetrics': {'hitRate': 0.5518518518518518,
#       'hits': 298,
#       'misses': 242}},
#     {'gameNumber': 3,
#      'noiseMetrics': {'hitRate': 0.6777777777777778, 'hits': 61, 'misses': 29},
#      'passMetrics': {'hitRate': 0.6844444444444444,
#       'hits': 308,
#       'misses': 142},
#      'subBlockMetrics': {'hitRate': 0.6833333333333333,
#       'hits': 369,
#       'misses': 171}},
#     {'gameNumber': 4,
#      'noiseMetrics': {'hitRate': 0.8222222222222222, 'hits': 74, 'misses': 16},
#      'passMetrics': {'hitRate': 0.7822222222222223, 'hits': 352, 'misses': 98},
#      'subBlockMetrics': {'hitRate': 0.7888888888888889,
#       'hits': 426,
#       'misses': 114}},
#     {'gameNumber': 5,
#      'noiseMetrics': {'hitRate': 0.4666666666666667, 'hits': 42, 'misses': 48},
#      'passMetrics': {'hitRate': 0.58, 'hits': 261, 'misses': 189},
#      'subBlockMetrics': {'hitRate': 0.5611111111111111,
#       'hits': 303,
#       'misses': 237}},
#     {'gameNumber': 6,
#      'noiseMetrics': {'hitRate': 0.7, 'hits': 63, 'misses': 27},
#      'passMetrics': {'hitRate': 0.7133333333333334,
#       'hits': 321,
#       'misses': 129},
#      'subBlockMetrics': {'hitRate': 0.7111111111111111,
#       'hits': 384,
#       'misses': 156}},
#     {'gameNumber': 7,
#      'noiseMetrics': {'hitRate': 0.7222222222222222, 'hits': 65, 'misses': 25},
#      'passMetrics': {'hitRate': 0.7666666666666667,
#       'hits': 345,
#       'misses': 105},
#      'subBlockMetrics': {'hitRate': 0.7592592592592593,
#       'hits': 410,
#       'misses': 130}}],
#    'hitRate': 0.6939153439153439,
#    'hits': 2623,
#    'misses': 1157,
#    'session': 'TRAIN'},
#   '-NwRVN-xk8bFbtx0xqL4': {'block': [{'gameNumber': 1,
#      'noiseMetrics': {'hitRate': 0.6861111111111111,
#       'hits': 247,
#       'misses': 113},
#      'passMetrics': {'hitRate': 0.7611111111111111, 'hits': 137, 'misses': 43},
#      'subBlockMetrics': {'hitRate': 0.7111111111111111,
#       'hits': 384,
#       'misses': 156}}],
#    'hitRate': 0.7111111111111111,
#    'hits': 384,
#    'misses': 156,
#    'session': 'AUTH1'},
#   '-NwzYDSrf7_ok7Dg-rkC': {'block': [{'gameNumber': 1,
#      'noiseMetrics': {'hitRate': 0.7611111111111111,
#       'hits': 274,
#       'misses': 86},
#      'passMetrics': {'hitRate': 0.7777777777777778, 'hits': 140, 'misses': 40},
#      'subBlockMetrics': {'hitRate': 0.7666666666666667,
#       'hits': 414,
#       'misses': 126}}],
#    'hitRate': 0.7666666666666667,
#    'hits': 414,
#    'misses': 126,
#    'session': 'AUTH2'},
#   'GAMETYPE': 'AUD',
#   'noteGenerateLag': 20,
#   'noteSpeed': 4,
#   'passSeq': ['K',
#    'J',
#    'K',
#    'F',
#    'L',
#    'J',
#    'D',
#    'F',
#    'K',
#    'L',
#    'D',
#    'K',
#    'S',
#    'K',
#    'D',
#    'L',
#    'S',
#    'D',
#    'S',
#    'F',
#    'F',
#    'J',
#    'S',
#    'J',
#    'L',
#    'F',
#    'D',
#    'J',
#    'L',
#    'K']},
#  '9QlFWUaX8YUvnJbOzqLHj9Hm7m13': {'GAMETYPE': 'AUD',
#   'passSeq': ['D',
#    'K',
#    'J',
#    'D',
#    'F',
#    'D',
#    'L',
#    'K',
#    'S',
#    'K',
#    'D',
#    'J',
#    'S',
#    'F',
#    'K',
#    'F',
#    'F',
#    'L',
#    'F',
#    'J',
#    'L',
#    'D',
#    'J',
#    'K',
#    'L',
#    'J',
#    'S',
#    'L',
#    'S',
#    'D']},
#  '9h37ieedjaThrNu036JihS7KRiJ3': {'-NvufMFFIqIDgmNOnYSM': {'block': [{'gameNumber': 1,
#      'noiseMetrics': {'hitRate': 0.6666666666666666, 'hits': 60, 'misses': 30},
#      'passMetrics': {'hitRate': 0.6844444444444444,
#       'hits': 308,
#       'misses': 142},
#      'subBlockMetrics': {'hitRate': 0.6814814814814815,
#       'hits': 368,
#       'misses': 172}},
#     {'gameNumber': 2,
#      'noiseMetrics': {'hitRate': 0.6111111111111112, 'hits': 55, 'misses': 35},
#      'passMetrics': {'hitRate': 0.6533333333333333,
#       'hits': 294,
#       'misses': 156},
#      'subBlockMetrics': {'hitRate': 0.6462962962962963,
#       'hits': 349,
#       'misses': 191}},
#     {'gameNumber': 3,
#      'noiseMetrics': {'hitRate': 0.7888888888888889, 'hits': 71, 'misses': 19},
#      'passMetrics': {'hitRate': 0.8422222222222222, 'hits': 379, 'misses': 71},
#      'subBlockMetrics': {'hitRate': 0.8333333333333334,
#       'hits': 450,
#       'misses': 90}},
#     {'gameNumber': 4,
#      'noiseMetrics': {'hitRate': 0.4888888888888889, 'hits': 44, 'misses': 46},
#      'passMetrics': {'hitRate': 0.6644444444444444,
#       'hits': 299,
#       'misses': 151},
#      'subBlockMetrics': {'hitRate': 0.6351851851851852,
#       'hits': 343,
#       'misses': 197}},
#     {'gameNumber': 5,
#      'noiseMetrics': {'hitRate': 0.5222222222222223, 'hits': 47, 'misses': 43},
#      'passMetrics': {'hitRate': 0.6288888888888889,
#       'hits': 283,
#       'misses': 167},
#      'subBlockMetrics': {'hitRate': 0.6111111111111112,
#       'hits': 330,
#       'misses': 210}},
#     {'gameNumber': 6,
#      'noiseMetrics': {'hitRate': 0.4, 'hits': 36, 'misses': 54},
#      'passMetrics': {'hitRate': 0.62, 'hits': 279, 'misses': 171},
#      'subBlockMetrics': {'hitRate': 0.5833333333333334,
#       'hits': 315,
#       'misses': 225}},
#     {'gameNumber': 7,
#      'noiseMetrics': {'hitRate': 0.6555555555555556, 'hits': 59, 'misses': 31},
#      'passMetrics': {'hitRate': 0.7377777777777778,
#       'hits': 332,
#       'misses': 118},
#      'subBlockMetrics': {'hitRate': 0.7240740740740741,
#       'hits': 391,
#       'misses': 149}}],
#    'hitRate': 0.6735449735449736,
#    'hits': 2546,
#    'misses': 1234,
#    'session': 'TRAIN'},
#   '-Nw_I_SU5_eclq5CldiC': {'block': [{'gameNumber': 1,
#      'noiseMetrics': {'hitRate': 0.6777777777777778,
#       'hits': 244,
#       'misses': 116},
#      'passMetrics': {'hitRate': 0.8222222222222222, 'hits': 148, 'misses': 32},
#      'subBlockMetrics': {'hitRate': 0.725925925925926,
#       'hits': 392,
#       'misses': 148}}],
#    'hitRate': 0.725925925925926,
#    'hits': 392,
#    'misses': 148,
#    'session': 'AUTH1'},
#   '-Nx3DD_4MH_1yqBS-llf': {'block': [{'gameNumber': 1,
#      'noiseMetrics': {'hitRate': 0.6861111111111111,
#       'hits': 247,
#       'misses': 113},
#      'passMetrics': {'hitRate': 0.7333333333333333, 'hits': 132, 'misses': 48},
#      'subBlockMetrics': {'hitRate': 0.7018518518518518,
#       'hits': 379,
#       'misses': 161}}],
#    'hitRate': 0.7018518518518518,
#    'hits': 379,
#    'misses': 161,
#    'session': 'AUTH2'},
#   'GAMETYPE': 'CONTROL',
#   'noteGenerateLag': 20,
#   'noteSpeed': 4,
#   'passSeq': ['S',
#    'L',
#    'L',
#    'J',
#    'J',
#    'L',
#    'L',
#    'D',
#    'D',
#    'K',
#    'L',
#    'K',
#    'S',
#    'K',
#    'S',
#    'J',
#    'D',
#    'J',
#    'K',
#    'J',
#    'K',
#    'F',
#    'F',
#    'K',
#    'S',
#    'F',
#    'D',
#    'L',
#    'L',
#    'F']},
#  'A0b5HPHEjqU9SrIbIHBMrCIDWS52': {'-NvqnlPcbUJXXOU7S4yW': {'block': [{'gameNumber': 1,
#      'noiseMetrics': {'hitRate': 0.6666666666666666, 'hits': 60, 'misses': 30},
#      'passMetrics': {'hitRate': 0.6088888888888889,
#       'hits': 274,
#       'misses': 176},
#      'subBlockMetrics': {'hitRate': 0.6185185185185185,
#       'hits': 334,
#       'misses': 206}},
#     {'gameNumber': 2,
#      'noiseMetrics': {'hitRate': 0.8333333333333334, 'hits': 75, 'misses': 15},
#      'passMetrics': {'hitRate': 0.7555555555555555,
#       'hits': 340,
#       'misses': 110},
#      'subBlockMetrics': {'hitRate': 0.7685185185185185,
#       'hits': 415,
#       'misses': 125}},
#     {'gameNumber': 3,
#      'noiseMetrics': {'hitRate': 0.6111111111111112, 'hits': 55, 'misses': 35},
#      'passMetrics': {'hitRate': 0.5733333333333334,
#       'hits': 258,
#       'misses': 192},
#      'subBlockMetrics': {'hitRate': 0.5796296296296296,
#       'hits': 313,
#       'misses': 227}},
#     {'gameNumber': 4,
#      'noiseMetrics': {'hitRate': 0.9444444444444444, 'hits': 85, 'misses': 5},
#      'passMetrics': {'hitRate': 0.8666666666666667, 'hits': 390, 'misses': 60},
#      'subBlockMetrics': {'hitRate': 0.8796296296296297,
#       'hits': 475,
#       'misses': 65}},
#     {'gameNumber': 5,
#      'noiseMetrics': {'hitRate': 0.5, 'hits': 45, 'misses': 45},
#      'passMetrics': {'hitRate': 0.52, 'hits': 234, 'misses': 216},
#      'subBlockMetrics': {'hitRate': 0.5166666666666667,
#       'hits': 279,
#       'misses': 261}},
#     {'gameNumber': 6,
#      'noiseMetrics': {'hitRate': 0.5, 'hits': 45, 'misses': 45},
#      'passMetrics': {'hitRate': 0.5511111111111111,
#       'hits': 248,
#       'misses': 202},
#      'subBlockMetrics': {'hitRate': 0.5425925925925926,
#       'hits': 293,
#       'misses': 247}},
#     {'gameNumber': 7,
#      'noiseMetrics': {'hitRate': 0.8666666666666667, 'hits': 78, 'misses': 12},
#      'passMetrics': {'hitRate': 0.86, 'hits': 387, 'misses': 63},
#      'subBlockMetrics': {'hitRate': 0.8611111111111112,
#       'hits': 465,
#       'misses': 75}}],
#    'hitRate': 0.680952380952381,
#    'hits': 2574,
#    'misses': 1206,
#    'session': 'TRAIN'},
#   '-Nw_HDfgNdzzK63EKX4Q': {'block': [{'gameNumber': 1,
#      'noiseMetrics': {'hitRate': 0.7194444444444444,
#       'hits': 259,
#       'misses': 101},
#      'passMetrics': {'hitRate': 0.7222222222222222, 'hits': 130, 'misses': 50},
#      'subBlockMetrics': {'hitRate': 0.7203703703703703,
#       'hits': 389,
#       'misses': 151}}],
#    'hitRate': 0.7203703703703703,
#    'hits': 389,
#    'misses': 151,
#    'session': 'AUTH1'},
#   '-Nwz1vZmCSAOcAuym2XW': {'block': [{'gameNumber': 1,
#      'noiseMetrics': {'hitRate': 0.7, 'hits': 252, 'misses': 108},
#      'passMetrics': {'hitRate': 0.6222222222222222, 'hits': 112, 'misses': 68},
#      'subBlockMetrics': {'hitRate': 0.674074074074074,
#       'hits': 364,
#       'misses': 176}}],
#    'hitRate': 0.674074074074074,
#    'hits': 364,
#    'misses': 176,
#    'session': 'AUTH2'},
#   'GAMETYPE': 'AUD',
#   'noteGenerateLag': 20,
#   'noteSpeed': 3,
#   'passSeq': ['K',
#    'J',
#    'K',
#    'F',
#    'L',
#    'J',
#    'D',
#    'F',
#    'K',
#    'L',
#    'D',
#    'K',
#    'S',
#    'K',
#    'D',
#    'L',
#    'S',
#    'D',
#    'S',
#    'F',
#    'F',
#    'J',
#    'S',
#    'J',
#    'L',
#    'F',
#    'D',
#    'J',
#    'L',
#    'K']},
#  'AkOKiuT0ArUEllVdm7QbvgkX0772': {'-NvuhHsb1kVjhveJhDBa': {'block': [{'gameNumber': 1,
#      'noiseMetrics': {'hitRate': 0.7111111111111111, 'hits': 64, 'misses': 26},
#      'passMetrics': {'hitRate': 0.7066666666666667,
#       'hits': 318,
#       'misses': 132},
#      'subBlockMetrics': {'hitRate': 0.7074074074074074,
#       'hits': 382,
#       'misses': 158}},
#     {'gameNumber': 2,
#      'noiseMetrics': {'hitRate': 0.5222222222222223, 'hits': 47, 'misses': 43},
#      'passMetrics': {'hitRate': 0.5466666666666666,
#       'hits': 246,
#       'misses': 204},
#      'subBlockMetrics': {'hitRate': 0.5425925925925926,
#       'hits': 293,
#       'misses': 247}},
#     {'gameNumber': 3,
#      'noiseMetrics': {'hitRate': 0.8777777777777778, 'hits': 79, 'misses': 11},
#      'passMetrics': {'hitRate': 0.8222222222222222, 'hits': 370, 'misses': 80},
#      'subBlockMetrics': {'hitRate': 0.8314814814814815,
#       'hits': 449,
#       'misses': 91}},
#     {'gameNumber': 4,
#      'noiseMetrics': {'hitRate': 0.9222222222222223, 'hits': 83, 'misses': 7},
#      'passMetrics': {'hitRate': 0.8311111111111111, 'hits': 374, 'misses': 76},
#      'subBlockMetrics': {'hitRate': 0.8462962962962963,
#       'hits': 457,
#       'misses': 83}},
#     {'gameNumber': 5,
#      'noiseMetrics': {'hitRate': 0.4222222222222222, 'hits': 38, 'misses': 52},
#      'passMetrics': {'hitRate': 0.46, 'hits': 207, 'misses': 243},
#      'subBlockMetrics': {'hitRate': 0.4537037037037037,
#       'hits': 245,
#       'misses': 295}},
#     {'gameNumber': 6,
#      'noiseMetrics': {'hitRate': 0.5777777777777777, 'hits': 52, 'misses': 38},
#      'passMetrics': {'hitRate': 0.5422222222222223,
#       'hits': 244,
#       'misses': 206},
#      'subBlockMetrics': {'hitRate': 0.5481481481481482,
#       'hits': 296,
#       'misses': 244}},
#     {'gameNumber': 7,
#      'noiseMetrics': {'hitRate': 0.7444444444444445, 'hits': 67, 'misses': 23},
#      'passMetrics': {'hitRate': 0.7555555555555555,
#       'hits': 340,
#       'misses': 110},
#      'subBlockMetrics': {'hitRate': 0.7537037037037037,
#       'hits': 407,
#       'misses': 133}}],
#    'hitRate': 0.669047619047619,
#    'hits': 2529,
#    'misses': 1251,
#    'session': 'TRAIN'},
#   '-NwTt1K7b9pZpY8Twd1D': {'block': [{'gameNumber': 1,
#      'noiseMetrics': {'hitRate': 0.6777777777777778,
#       'hits': 244,
#       'misses': 116},
#      'passMetrics': {'hitRate': 0.7222222222222222, 'hits': 130, 'misses': 50},
#      'subBlockMetrics': {'hitRate': 0.6925925925925925,
#       'hits': 374,
#       'misses': 166}}],
#    'hitRate': 0.6925925925925925,
#    'hits': 374,
#    'misses': 166,
#    'session': 'AUTH1'},
#   '-Nx2xiJFgjfZa4WVI8mJ': {'block': [{'gameNumber': 1,
#      'noiseMetrics': {'hitRate': 0.7305555555555555,
#       'hits': 263,
#       'misses': 97},
#      'passMetrics': {'hitRate': 0.6444444444444445, 'hits': 116, 'misses': 64},
#      'subBlockMetrics': {'hitRate': 0.7018518518518518,
#       'hits': 379,
#       'misses': 161}}],
#    'hitRate': 0.7018518518518518,
#    'hits': 379,
#    'misses': 161,
#    'session': 'AUTH2'},
#   'GAMETYPE': 'CONTROL',
#   'noteGenerateLag': 35,
#   'noteSpeed': 3,
#   'passSeq': ['K',
#    'J',
#    'K',
#    'F',
#    'L',
#    'J',
#    'D',
#    'F',
#    'K',
#    'L',
#    'D',
#    'K',
#    'S',
#    'K',
#    'D',
#    'L',
#    'S',
#    'D',
#    'S',
#    'F',
#    'F',
#    'J',
#    'S',
#    'J',
#    'L',
#    'F',
#    'D',
#    'J',
#    'L',
#    'K']},
#  'AyFpXZsvJiXRtg1ztcUhwHs2YKq2': {'-NvqY3zZfb1bnCpXOgWv': {'block': [{'gameNumber': 1,
#      'noiseMetrics': {'hitRate': 0.6777777777777778, 'hits': 61, 'misses': 29},
#      'passMetrics': {'hitRate': 0.6844444444444444,
#       'hits': 308,
#       'misses': 142},
#      'subBlockMetrics': {'hitRate': 0.6833333333333333,
#       'hits': 369,
#       'misses': 171}},
#     {'gameNumber': 2,
#      'noiseMetrics': {'hitRate': 0.6777777777777778, 'hits': 61, 'misses': 29},
#      'passMetrics': {'hitRate': 0.7088888888888889,
#       'hits': 319,
#       'misses': 131},
#      'subBlockMetrics': {'hitRate': 0.7037037037037037,
#       'hits': 380,
#       'misses': 160}},
#     {'gameNumber': 3,
#      'noiseMetrics': {'hitRate': 0.6444444444444445, 'hits': 58, 'misses': 32},
#      'passMetrics': {'hitRate': 0.6955555555555556,
#       'hits': 313,
#       'misses': 137},
#      'subBlockMetrics': {'hitRate': 0.687037037037037,
#       'hits': 371,
#       'misses': 169}},
#     {'gameNumber': 4,
#      'noiseMetrics': {'hitRate': 0.7, 'hits': 63, 'misses': 27},
#      'passMetrics': {'hitRate': 0.6933333333333334,
#       'hits': 312,
#       'misses': 138},
#      'subBlockMetrics': {'hitRate': 0.6944444444444444,
#       'hits': 375,
#       'misses': 165}},
#     {'gameNumber': 5,
#      'noiseMetrics': {'hitRate': 0.7777777777777778, 'hits': 70, 'misses': 20},
#      'passMetrics': {'hitRate': 0.84, 'hits': 378, 'misses': 72},
#      'subBlockMetrics': {'hitRate': 0.8296296296296296,
#       'hits': 448,
#       'misses': 92}},
#     {'gameNumber': 6,
#      'noiseMetrics': {'hitRate': 0.6888888888888889, 'hits': 62, 'misses': 28},
#      'passMetrics': {'hitRate': 0.8355555555555556, 'hits': 376, 'misses': 74},
#      'subBlockMetrics': {'hitRate': 0.8111111111111111,
#       'hits': 438,
#       'misses': 102}},
#     {'gameNumber': 7,
#      'noiseMetrics': {'hitRate': 0.7, 'hits': 63, 'misses': 27},
#      'passMetrics': {'hitRate': 0.7822222222222223, 'hits': 352, 'misses': 98},
#      'subBlockMetrics': {'hitRate': 0.7685185185185185,
#       'hits': 415,
#       'misses': 125}}],
#    'hitRate': 0.7396825396825397,
#    'hits': 2796,
#    'misses': 984,
#    'session': 'TRAIN'},
#   '-Nw_FwR52-hy1pyin3a3': {'block': [{'gameNumber': 1,
#      'noiseMetrics': {'hitRate': 0.7444444444444445,
#       'hits': 268,
#       'misses': 92},
#      'passMetrics': {'hitRate': 0.7388888888888889, 'hits': 133, 'misses': 47},
#      'subBlockMetrics': {'hitRate': 0.7425925925925926,
#       'hits': 401,
#       'misses': 139}}],
#    'hitRate': 0.7425925925925926,
#    'hits': 401,
#    'misses': 139,
#    'session': 'AUTH1'},
#   '-Nx7s1fBVjtuguN9Jjd4': {'block': [{'gameNumber': 1,
#      'noiseMetrics': {'hitRate': 0.6305555555555555,
#       'hits': 227,
#       'misses': 133},
#      'passMetrics': {'hitRate': 0.8222222222222222, 'hits': 148, 'misses': 32},
#      'subBlockMetrics': {'hitRate': 0.6944444444444444,
#       'hits': 375,
#       'misses': 165}}],
#    'hitRate': 0.6944444444444444,
#    'hits': 375,
#    'misses': 165,
#    'session': 'AUTH2'},
#   'GAMETYPE': 'VIS',
#   'noteGenerateLag': 20,
#   'noteSpeed': 3,
#   'passSeq': ['S',
#    'L',
#    'L',
#    'J',
#    'J',
#    'L',
#    'L',
#    'D',
#    'D',
#    'K',
#    'L',
#    'K',
#    'S',
#    'K',
#    'S',
#    'J',
#    'D',
#    'J',
#    'K',
#    'J',
#    'K',
#    'F',
#    'F',
#    'K',
#    'S',
#    'F',
#    'D',
#    'L',
#    'L',
#    'F']},
#  'BKvPzU9VM6XpE3HduKzR8EcQGbp2': {'-Nw59np_blI1ZhzOTDJR': {'block': [{'gameNumber': 1,
#      'noiseMetrics': {'hitRate': 0.6888888888888889, 'hits': 62, 'misses': 28},
#      'passMetrics': {'hitRate': 0.72, 'hits': 324, 'misses': 126},
#      'subBlockMetrics': {'hitRate': 0.7148148148148148,
#       'hits': 386,
#       'misses': 154}},
#     {'gameNumber': 2,
#      'noiseMetrics': {'hitRate': 0.6555555555555556, 'hits': 59, 'misses': 31},
#      'passMetrics': {'hitRate': 0.6844444444444444,
#       'hits': 308,
#       'misses': 142},
#      'subBlockMetrics': {'hitRate': 0.6796296296296296,
#       'hits': 367,
#       'misses': 173}},
#     {'gameNumber': 3,
#      'noiseMetrics': {'hitRate': 0.6666666666666666, 'hits': 60, 'misses': 30},
#      'passMetrics': {'hitRate': 0.7377777777777778,
#       'hits': 332,
#       'misses': 118},
#      'subBlockMetrics': {'hitRate': 0.725925925925926,
#       'hits': 392,
#       'misses': 148}},
#     {'gameNumber': 4,
#      'noiseMetrics': {'hitRate': 0.9333333333333333, 'hits': 84, 'misses': 6},
#      'passMetrics': {'hitRate': 0.8711111111111111, 'hits': 392, 'misses': 58},
#      'subBlockMetrics': {'hitRate': 0.8814814814814815,
#       'hits': 476,
#       'misses': 64}},
#     {'gameNumber': 5,
#      'noiseMetrics': {'hitRate': 0.8333333333333334, 'hits': 75, 'misses': 15},
#      'passMetrics': {'hitRate': 0.9044444444444445, 'hits': 407, 'misses': 43},
#      'subBlockMetrics': {'hitRate': 0.8925925925925926,
#       'hits': 482,
#       'misses': 58}},
#     {'gameNumber': 6,
#      'noiseMetrics': {'hitRate': 0.8111111111111111, 'hits': 73, 'misses': 17},
#      'passMetrics': {'hitRate': 0.8666666666666667, 'hits': 390, 'misses': 60},
#      'subBlockMetrics': {'hitRate': 0.8574074074074074,
#       'hits': 463,
#       'misses': 77}},
#     {'gameNumber': 7,
#      'noiseMetrics': {'hitRate': 0.7888888888888889, 'hits': 71, 'misses': 19},
#      'passMetrics': {'hitRate': 0.8311111111111111, 'hits': 374, 'misses': 76},
#      'subBlockMetrics': {'hitRate': 0.8240740740740741,
#       'hits': 445,
#       'misses': 95}}],
#    'hitRate': 0.7965608465608466,
#    'hits': 3011,
#    'misses': 769,
#    'session': 'TRAIN'},
#   '-Nw_4KHeJKHWrkg1nyi2': {'block': [{'gameNumber': 1,
#      'noiseMetrics': {'hitRate': 0.7777777777777778,
#       'hits': 280,
#       'misses': 80},
#      'passMetrics': {'hitRate': 0.7777777777777778, 'hits': 140, 'misses': 40},
#      'subBlockMetrics': {'hitRate': 0.7777777777777778,
#       'hits': 420,
#       'misses': 120}}],
#    'hitRate': 0.7777777777777778,
#    'hits': 420,
#    'misses': 120,
#    'session': 'AUTH1'},
#   '-Nx87oQUsqTPKI2Yyy1E': {'block': [{'gameNumber': 1,
#      'noiseMetrics': {'hitRate': 0.7361111111111112,
#       'hits': 265,
#       'misses': 95},
#      'passMetrics': {'hitRate': 0.7944444444444444, 'hits': 143, 'misses': 37},
#      'subBlockMetrics': {'hitRate': 0.7555555555555555,
#       'hits': 408,
#       'misses': 132}}],
#    'hitRate': 0.7555555555555555,
#    'hits': 408,
#    'misses': 132,
#    'session': 'AUTH2'},
#   'GAMETYPE': 'VIS',
#   'noteGenerateLag': 20,
#   'noteSpeed': 12,
#   'passSeq': ['K',
#    'J',
#    'K',
#    'F',
#    'L',
#    'J',
#    'D',
#    'F',
#    'K',
#    'L',
#    'D',
#    'K',
#    'S',
#    'K',
#    'D',
#    'L',
#    'S',
#    'D',
#    'S',
#    'F',
# ...
#   'noteGenerateLag': 36,
#   'noteSpeed': 3,
#   'passSeq': ['S',
#    'L',
#    'L',
#    'J',
#    'J',
#    'L',
#    'L',
#    'D',
#    'D',
#    'K',
#    'L',
#    'K',
#    'S',
#    'K',
#    'S',
#    'J',
#    'D',
#    'J',
#    'K',
#    'J',
#    'K',
#    'F',
#    'F',
#    'K',
#    'S',
#    'F',
#    'D',
#    'L',
#    'L',
#    'F']},
#  'umG8DQRaeVd6RPOJfoLKNdclG8e2': {'-NvugM7l43EXpNHxf9qz': {'block': [{'gameNumber': 1,
#      'noiseMetrics': {'hitRate': 0.7333333333333333, 'hits': 66, 'misses': 24},
#      'passMetrics': {'hitRate': 0.6844444444444444,
#       'hits': 308,
#       'misses': 142},
#      'subBlockMetrics': {'hitRate': 0.6925925925925925,
#       'hits': 374,
#       'misses': 166}},
#     {'gameNumber': 2,
#      'noiseMetrics': {'hitRate': 0.7, 'hits': 63, 'misses': 27},
#      'passMetrics': {'hitRate': 0.6222222222222222,
#       'hits': 280,
#       'misses': 170},
#      'subBlockMetrics': {'hitRate': 0.6351851851851852,
#       'hits': 343,
#       'misses': 197}},
#     {'gameNumber': 3,
#      'noiseMetrics': {'hitRate': 0.8111111111111111, 'hits': 73, 'misses': 17},
#      'passMetrics': {'hitRate': 0.8022222222222222, 'hits': 361, 'misses': 89},
#      'subBlockMetrics': {'hitRate': 0.8037037037037037,
#       'hits': 434,
#       'misses': 106}},
#     {'gameNumber': 4,
#      'noiseMetrics': {'hitRate': 0.5333333333333333, 'hits': 48, 'misses': 42},
#      'passMetrics': {'hitRate': 0.6222222222222222,
#       'hits': 280,
#       'misses': 170},
#      'subBlockMetrics': {'hitRate': 0.6074074074074074,
#       'hits': 328,
#       'misses': 212}},
#     {'gameNumber': 5,
#      'noiseMetrics': {'hitRate': 0.5111111111111111, 'hits': 46, 'misses': 44},
#      'passMetrics': {'hitRate': 0.5488888888888889,
#       'hits': 247,
#       'misses': 203},
#      'subBlockMetrics': {'hitRate': 0.5425925925925926,
#       'hits': 293,
#       'misses': 247}},
#     {'gameNumber': 6,
#      'noiseMetrics': {'hitRate': 0.8333333333333334, 'hits': 75, 'misses': 15},
#      'passMetrics': {'hitRate': 0.8666666666666667, 'hits': 390, 'misses': 60},
#      'subBlockMetrics': {'hitRate': 0.8611111111111112,
#       'hits': 465,
#       'misses': 75}},
#     {'gameNumber': 7,
#      'noiseMetrics': {'hitRate': 0.7888888888888889, 'hits': 71, 'misses': 19},
#      'passMetrics': {'hitRate': 0.7444444444444445,
#       'hits': 335,
#       'misses': 115},
#      'subBlockMetrics': {'hitRate': 0.7518518518518519,
#       'hits': 406,
#       'misses': 134}}],
#    'hitRate': 0.6992063492063492,
#    'hits': 2643,
#    'misses': 1137,
#    'session': 'TRAIN'},
#   '-NwTmTX_q7jYByUT16Qy': {'block': [{'gameNumber': 1,
#      'noiseMetrics': {'hitRate': 0.6805555555555556,
#       'hits': 245,
#       'misses': 115},
#      'passMetrics': {'hitRate': 0.6833333333333333, 'hits': 123, 'misses': 57},
#      'subBlockMetrics': {'hitRate': 0.6814814814814815,
#       'hits': 368,
#       'misses': 172}}],
#    'hitRate': 0.6814814814814815,
#    'hits': 368,
#    'misses': 172,
#    'session': 'AUTH1'},
#   '-Nx323zgjFJWCVGSiujN': {'block': [{'gameNumber': 1,
#      'noiseMetrics': {'hitRate': 0.6722222222222223,
#       'hits': 242,
#       'misses': 118},
#      'passMetrics': {'hitRate': 0.7333333333333333, 'hits': 132, 'misses': 48},
#      'subBlockMetrics': {'hitRate': 0.6925925925925925,
#       'hits': 374,
#       'misses': 166}}],
#    'hitRate': 0.6925925925925925,
#    'hits': 374,
#    'misses': 166,
#    'session': 'AUTH2'},
#   'GAMETYPE': 'CONTROL',
#   'noteGenerateLag': 20,
#   'noteSpeed': 3,
#   'passSeq': ['K',
#    'J',
#    'K',
#    'F',
#    'L',
#    'J',
#    'D',
#    'F',
#    'K',
#    'L',
#    'D',
#    'K',
#    'S',
#    'K',
#    'D',
#    'L',
#    'S',
#    'D',
#    'S',
#    'F',
#    'F',
#    'J',
#    'S',
#    'J',
#    'L',
#    'F',
#    'D',
#    'J',
#    'L',
#    'K']},
#  'wFRIlVm6H0N0WjSBNg3EMMaTf0H3': {'-Nw0Jw46HbQB7XT3Y-o9': {'block': [{'gameNumber': 1,
#      'noiseMetrics': {'hitRate': 0.6777777777777778, 'hits': 61, 'misses': 29},
#      'passMetrics': {'hitRate': 0.6, 'hits': 270, 'misses': 180},
#      'subBlockMetrics': {'hitRate': 0.6129629629629629,
#       'hits': 331,
#       'misses': 209}},
#     {'gameNumber': 2,
#      'noiseMetrics': {'hitRate': 0.8666666666666667, 'hits': 78, 'misses': 12},
#      'passMetrics': {'hitRate': 0.9088888888888889, 'hits': 409, 'misses': 41},
#      'subBlockMetrics': {'hitRate': 0.9018518518518519,
#       'hits': 487,
#       'misses': 53}},
#     {'gameNumber': 3,
#      'noiseMetrics': {'hitRate': 0.5111111111111111, 'hits': 46, 'misses': 44},
#      'passMetrics': {'hitRate': 0.4222222222222222,
#       'hits': 190,
#       'misses': 260},
#      'subBlockMetrics': {'hitRate': 0.43703703703703706,
#       'hits': 236,
#       'misses': 304}},
#     {'gameNumber': 4,
#      'noiseMetrics': {'hitRate': 0.8111111111111111, 'hits': 73, 'misses': 17},
#      'passMetrics': {'hitRate': 0.7777777777777778,
#       'hits': 350,
#       'misses': 100},
#      'subBlockMetrics': {'hitRate': 0.7833333333333333,
#       'hits': 423,
#       'misses': 117}},
#     {'gameNumber': 5,
#      'noiseMetrics': {'hitRate': 0.7666666666666667, 'hits': 69, 'misses': 21},
#      'passMetrics': {'hitRate': 0.7355555555555555,
#       'hits': 331,
#       'misses': 119},
#      'subBlockMetrics': {'hitRate': 0.7407407407407407,
#       'hits': 400,
#       'misses': 140}},
#     {'gameNumber': 6,
#      'noiseMetrics': {'hitRate': 0.7222222222222222, 'hits': 65, 'misses': 25},
#      'passMetrics': {'hitRate': 0.66, 'hits': 297, 'misses': 153},
#      'subBlockMetrics': {'hitRate': 0.6703703703703704,
#       'hits': 362,
#       'misses': 178}},
#     {'gameNumber': 7,
#      'noiseMetrics': {'hitRate': 0.7777777777777778, 'hits': 70, 'misses': 20},
#      'passMetrics': {'hitRate': 0.6955555555555556,
#       'hits': 313,
#       'misses': 137},
#      'subBlockMetrics': {'hitRate': 0.7092592592592593,
#       'hits': 383,
#       'misses': 157}}],
#    'hitRate': 0.6936507936507936,
#    'hits': 2622,
#    'misses': 1158,
#    'session': 'TRAIN'},
#   '-NwTicnl58pcTv-0PXEZ': {'block': [{'gameNumber': 1,
#      'noiseMetrics': {'hitRate': 0.6972222222222222,
#       'hits': 251,
#       'misses': 109},
#      'passMetrics': {'hitRate': 0.6666666666666666, 'hits': 120, 'misses': 60},
#      'subBlockMetrics': {'hitRate': 0.687037037037037,
#       'hits': 371,
#       'misses': 169}}],
#    'hitRate': 0.687037037037037,
#    'hits': 371,
#    'misses': 169,
#    'session': 'AUTH1'},
#   '-Nx32pzYASAZzltGuPLx': {'block': [{'gameNumber': 1,
#      'noiseMetrics': {'hitRate': 0.7638888888888888,
#       'hits': 275,
#       'misses': 85},
#      'passMetrics': {'hitRate': 0.7333333333333333, 'hits': 132, 'misses': 48},
#      'subBlockMetrics': {'hitRate': 0.7537037037037037,
#       'hits': 407,
#       'misses': 133}}],
#    'hitRate': 0.7537037037037037,
#    'hits': 407,
#    'misses': 133,
#    'session': 'AUTH2'},
#   'GAMETYPE': 'CONTROL',
#   'noteGenerateLag': 20,
#   'noteSpeed': 3,
#   'passSeq': ['D',
#    'K',
#    'J',
#    'D',
#    'F',
#    'D',
#    'L',
#    'K',
#    'S',
#    'K',
#    'D',
#    'J',
#    'S',
#    'F',
#    'K',
#    'F',
#    'F',
#    'L',
#    'F',
#    'J',
#    'L',
#    'D',
#    'J',
#    'K',
#    'L',
#    'J',
#    'S',
#    'L',
#    'S',
#    'D']},
#  'xTyF5REL0bUIT99Hkx2YCWC75572': {'-Nvql-hCjTPRJarXs7Zd': {'block': [{'gameNumber': 1,
#      'noiseMetrics': {'hitRate': 0.6555555555555556, 'hits': 59, 'misses': 31},
#      'passMetrics': {'hitRate': 0.6911111111111111,
#       'hits': 311,
#       'misses': 139},
#      'subBlockMetrics': {'hitRate': 0.6851851851851852,
#       'hits': 370,
#       'misses': 170}},
#     {'gameNumber': 2,
#      'noiseMetrics': {'hitRate': 0.7444444444444445, 'hits': 67, 'misses': 23},
#      'passMetrics': {'hitRate': 0.7111111111111111,
#       'hits': 320,
#       'misses': 130},
#      'subBlockMetrics': {'hitRate': 0.7166666666666667,
#       'hits': 387,
#       'misses': 153}},
#     {'gameNumber': 3,
#      'noiseMetrics': {'hitRate': 0.7111111111111111, 'hits': 64, 'misses': 26},
#      'passMetrics': {'hitRate': 0.7044444444444444,
#       'hits': 317,
#       'misses': 133},
#      'subBlockMetrics': {'hitRate': 0.7055555555555556,
#       'hits': 381,
#       'misses': 159}},
#     {'gameNumber': 4,
#      'noiseMetrics': {'hitRate': 0.7777777777777778, 'hits': 70, 'misses': 20},
#      'passMetrics': {'hitRate': 0.7777777777777778,
#       'hits': 350,
#       'misses': 100},
#      'subBlockMetrics': {'hitRate': 0.7777777777777778,
#       'hits': 420,
#       'misses': 120}},
#     {'gameNumber': 5,
#      'noiseMetrics': {'hitRate': 0.8555555555555555, 'hits': 77, 'misses': 13},
#      'passMetrics': {'hitRate': 0.7644444444444445,
#       'hits': 344,
#       'misses': 106},
#      'subBlockMetrics': {'hitRate': 0.7796296296296297,
#       'hits': 421,
#       'misses': 119}},
#     {'gameNumber': 6,
#      'noiseMetrics': {'hitRate': 0.7, 'hits': 63, 'misses': 27},
#      'passMetrics': {'hitRate': 0.7977777777777778, 'hits': 359, 'misses': 91},
#      'subBlockMetrics': {'hitRate': 0.7814814814814814,
#       'hits': 422,
#       'misses': 118}},
#     {'gameNumber': 7,
#      'noiseMetrics': {'hitRate': 0.8111111111111111, 'hits': 73, 'misses': 17},
#      'passMetrics': {'hitRate': 0.8355555555555556, 'hits': 376, 'misses': 74},
#      'subBlockMetrics': {'hitRate': 0.8314814814814815,
#       'hits': 449,
#       'misses': 91}}],
#    'hitRate': 0.753968253968254,
#    'hits': 2850,
#    'misses': 930,
#    'session': 'TRAIN'},
#   '-NwPey8nLIwMFexnWTFK': {'block': [{'gameNumber': 1,
#      'noiseMetrics': {'hitRate': 0.7416666666666667,
#       'hits': 267,
#       'misses': 93},
#      'passMetrics': {'hitRate': 0.7666666666666667, 'hits': 138, 'misses': 42},
#      'subBlockMetrics': {'hitRate': 0.75, 'hits': 405, 'misses': 135}}],
#    'hitRate': 0.75,
#    'hits': 405,
#    'misses': 135,
#    'session': 'AUTH1'},
#   '-NwywcJCtyXvr_81H-Il': {'block': [{'gameNumber': 1,
#      'noiseMetrics': {'hitRate': 0.7194444444444444,
#       'hits': 259,
#       'misses': 101},
#      'passMetrics': {'hitRate': 0.8777777777777778, 'hits': 158, 'misses': 22},
#      'subBlockMetrics': {'hitRate': 0.7722222222222223,
#       'hits': 417,
#       'misses': 123}}],
#    'hitRate': 0.7722222222222223,
#    'hits': 417,
#    'misses': 123,
#    'session': 'AUTH2'},
#   'GAMETYPE': 'AUD',
#   'noteGenerateLag': 20,
#   'noteSpeed': 8,
#   'passSeq': ['K',
#    'J',
#    'K',
#    'F',
#    'L',
#    'J',
#    'D',
#    'F',
#    'K',
#    'L',
#    'D',
#    'K',
#    'S',
#    'K',
#    'D',
#    'L',
#    'S',
#    'D',
#    'S',
#    'F',
#    'F',
#    'J',
#    'S',
#    'J',
#    'L',
#    'F',
#    'D',
#    'J',
#    'L',
#    'K']},
#  'y00ZoK3RqXad5jH5FESwAXkd0Ki1': {'-Nw54WBjhRADuxoqPjVt': {'block': [{'gameNumber': 1,
#      'noiseMetrics': {'hitRate': 0.7111111111111111, 'hits': 64, 'misses': 26},
#      'passMetrics': {'hitRate': 0.64, 'hits': 288, 'misses': 162},
#      'subBlockMetrics': {'hitRate': 0.6518518518518519,
#       'hits': 352,
#       'misses': 188}},
#     {'gameNumber': 2,
#      'noiseMetrics': {'hitRate': 0.8111111111111111, 'hits': 73, 'misses': 17},
#      'passMetrics': {'hitRate': 0.7288888888888889,
#       'hits': 328,
#       'misses': 122},
#      'subBlockMetrics': {'hitRate': 0.7425925925925926,
#       'hits': 401,
#       'misses': 139}},
#     {'gameNumber': 3,
#      'noiseMetrics': {'hitRate': 0.8666666666666667, 'hits': 78, 'misses': 12},
#      'passMetrics': {'hitRate': 0.86, 'hits': 387, 'misses': 63},
#      'subBlockMetrics': {'hitRate': 0.8611111111111112,
#       'hits': 465,
#       'misses': 75}},
#     {'gameNumber': 4,
#      'noiseMetrics': {'hitRate': 0.6777777777777778, 'hits': 61, 'misses': 29},
#      'passMetrics': {'hitRate': 0.68, 'hits': 306, 'misses': 144},
#      'subBlockMetrics': {'hitRate': 0.6796296296296296,
#       'hits': 367,
#       'misses': 173}},
#     {'gameNumber': 5,
#      'noiseMetrics': {'hitRate': 0.7222222222222222, 'hits': 65, 'misses': 25},
#      'passMetrics': {'hitRate': 0.7022222222222222,
#       'hits': 316,
#       'misses': 134},
#      'subBlockMetrics': {'hitRate': 0.7055555555555556,
#       'hits': 381,
#       'misses': 159}},
#     {'gameNumber': 6,
#      'noiseMetrics': {'hitRate': 0.6888888888888889, 'hits': 62, 'misses': 28},
#      'passMetrics': {'hitRate': 0.6911111111111111,
#       'hits': 311,
#       'misses': 139},
#      'subBlockMetrics': {'hitRate': 0.6907407407407408,
#       'hits': 373,
#       'misses': 167}},
#     {'gameNumber': 7,
#      'noiseMetrics': {'hitRate': 0.7222222222222222, 'hits': 65, 'misses': 25},
#      'passMetrics': {'hitRate': 0.7533333333333333,
#       'hits': 339,
#       'misses': 111},
#      'subBlockMetrics': {'hitRate': 0.7481481481481481,
#       'hits': 404,
#       'misses': 136}}],
#    'hitRate': 0.7256613756613757,
#    'hits': 2743,
#    'misses': 1037,
#    'session': 'TRAIN'},
#   '-Nw_D1vpQK-GIRKF6IQX': {'block': [{'gameNumber': 1,
#      'noiseMetrics': {'hitRate': 0.7972222222222223,
#       'hits': 287,
#       'misses': 73},
#      'passMetrics': {'hitRate': 0.6611111111111111, 'hits': 119, 'misses': 61},
#      'subBlockMetrics': {'hitRate': 0.7518518518518519,
#       'hits': 406,
#       'misses': 134}}],
#    'hitRate': 0.7518518518518519,
#    'hits': 406,
#    'misses': 134,
#    'session': 'AUTH1'},
#   '-Nx87bRUXyxGNPXSjbRj': {'block': [{'gameNumber': 1,
#      'noiseMetrics': {'hitRate': 0.7388888888888889,
#       'hits': 266,
#       'misses': 94},
#      'passMetrics': {'hitRate': 0.5944444444444444, 'hits': 107, 'misses': 73},
#      'subBlockMetrics': {'hitRate': 0.6907407407407408,
#       'hits': 373,
#       'misses': 167}}],
#    'hitRate': 0.6907407407407408,
#    'hits': 373,
#    'misses': 167,
#    'session': 'AUTH2'},
#   'GAMETYPE': 'VIS',
#   'noteGenerateLag': 20,
#   'noteSpeed': 3,
#   'passSeq': ['K',
#    'J',
#    'K',
#    'F',
#    'L',
#    'J',
#    'D',
#    'F',
#    'K',
#    'L',
#    'D',
#    'K',
#    'S',
#    'K',
#    'D',
#    'L',
#    'S',
#    'D',
#    'S',
#    'F',
#    'F',
#    'J',
#    'S',
#    'J',
#    'L',
#    'F',
#    'D',
#    'J',
#    'L',
#    'K']},
#  'ydFbNfL3WSeGXeHYprAbWXhsihh2': {'-NvgUOAacYakWPhX53cR': {'block': [{'gameNumber': 1,
#      'noiseMetrics': {'hitRate': 0.5222222222222223, 'hits': 47, 'misses': 43},
#      'passMetrics': {'hitRate': 0.6333333333333333,
#       'hits': 285,
#       'misses': 165},
#      'subBlockMetrics': {'hitRate': 0.6148148148148148,
#       'hits': 332,
#       'misses': 208}},
#     {'gameNumber': 2,
#      'noiseMetrics': {'hitRate': 0.7222222222222222, 'hits': 65, 'misses': 25},
#      'passMetrics': {'hitRate': 0.8644444444444445, 'hits': 389, 'misses': 61},
#      'subBlockMetrics': {'hitRate': 0.8407407407407408,
#       'hits': 454,
#       'misses': 86}},
#     {'gameNumber': 3,
#      'noiseMetrics': {'hitRate': 0.5888888888888889, 'hits': 53, 'misses': 37},
#      'passMetrics': {'hitRate': 0.5377777777777778,
#       'hits': 242,
#       'misses': 208},
#      'subBlockMetrics': {'hitRate': 0.5462962962962963,
#       'hits': 295,
#       'misses': 245}},
#     {'gameNumber': 4,
#      'noiseMetrics': {'hitRate': 0.7333333333333333, 'hits': 66, 'misses': 24},
#      'passMetrics': {'hitRate': 0.7066666666666667,
#       'hits': 318,
#       'misses': 132},
#      'subBlockMetrics': {'hitRate': 0.7111111111111111,
#       'hits': 384,
#       'misses': 156}},
#     {'gameNumber': 5,
#      'noiseMetrics': {'hitRate': 0.7111111111111111, 'hits': 64, 'misses': 26},
#      'passMetrics': {'hitRate': 0.8155555555555556, 'hits': 367, 'misses': 83},
#      'subBlockMetrics': {'hitRate': 0.7981481481481482,
#       'hits': 431,
#       'misses': 109}},
#     {'gameNumber': 6,
#      'noiseMetrics': {'hitRate': 0.6333333333333333, 'hits': 57, 'misses': 33},
#      'passMetrics': {'hitRate': 0.6088888888888889,
#       'hits': 274,
#       'misses': 176},
#      'subBlockMetrics': {'hitRate': 0.6129629629629629,
#       'hits': 331,
#       'misses': 209}},
#     {'gameNumber': 7,
#      'noiseMetrics': {'hitRate': 0.6444444444444445, 'hits': 58, 'misses': 32},
#      'passMetrics': {'hitRate': 0.6733333333333333,
#       'hits': 303,
#       'misses': 147},
#      'subBlockMetrics': {'hitRate': 0.6685185185185185,
#       'hits': 361,
#       'misses': 179}}],
#    'hitRate': 0.6846560846560846,
#    'hits': 2588,
#    'misses': 1192,
#    'session': 'TRAIN'},
#   'GAMETYPE': 'AUD',
#   'noteGenerateLag': 20,
#   'noteSpeed': 3,
#   'passSeq': ['K',
#    'J',
#    'K',
#    'F',
#    'L',
#    'J',
#    'D',
#    'F',
#    'K',
#    'L',
#    'D',
#    'K',
#    'S',
#    'K',
#    'D',
#    'L',
#    'S',
#    'D',
#    'S',
#    'F',
#    'F',
#    'J',
#    'S',
#    'J',
#    'L',
#    'F',
#    'D',
#    'J',
#    'L',
#    'K']}}

# %%
user_ids = list(firebase_data.keys())
len(user_ids) ##  check if consistent with firebase auth db (NR - yes letsgo)
# Out:
# 88

# %%
def get_sessions(user_id):
    user_data = firebase_data[user_id]
    session_ids = list(user_data.keys())
    # only dictionaries in the first level are sessions (rest are stats)
    session_ids = [session_id for session_id in session_ids if isinstance(user_data[session_id], dict)]
    return [user_data[session_id] for session_id in session_ids]

print(user_ids[1])
print(len(get_sessions(user_ids[1])))
# Out:
# 267spXKQrOQxNGhW9Mj19RVBZnF3
# 3

# %%
# Remove any user_ids that do not have 3 sessions in the data dict
valid_user_ids = [user_id for user_id in user_ids if len(get_sessions(user_id)) == 3]
print("After cleaning:", len(valid_user_ids))
# Out:
# After cleaning: 70

# %%
# show the invalid user_ids
invalid_user_ids = [user_id for user_id in user_ids if user_id not in valid_user_ids]
invalid_user_ids
# Out:
# ['0AT3q4mTMncZcXXdMv8pkQIXdqk1',
#  '61Alts16Drd976ojNN40qLI0OYf2',
#  '9QlFWUaX8YUvnJbOzqLHj9Hm7m13',
#  'F8h1ogBE7YWzfrMxHZXqVWRugDj1',
#  'ILvZTNvwCJU2yelJbt2ec1frgTd2',
#  'JX1MSnsjz5YX3YYpFzq8k7PNrkF2',
#  'QBQ7IYCMNZgIrRo6xyIWaAE8zfh2',
#  'ZKxy4N3cRheVWvkBidVPlhqpUys1',
#  '_gamedata',
#  'aCdtxO7Yt8NS4bUEcVIwO8hXxrp2',
#  'al1J9obEr8RGWeegYm6pdMUukTy1',
#  'cGCLDYJZjufGLDzs2FGvzB2K7G13',
#  'iqDkwDQyBkbrSJuyNP8MtppVfw33',
#  'jjvUl1JzWCd1tOZiMk7b4c3LxUg2',
#  'knhgxWpBpgVuwufdvzxJp9tmhYD3',
#  'nmEA2h7hZde6WDqxdHUBxndmiuz1',
#  'oV4HGMAODpaxKUcCQHdIzfn3pPB3',
#  'ydFbNfL3WSeGXeHYprAbWXhsihh2']

# %% [markdown]
# ## Data Restructuring
# Three dataframes to be made with the following structure:
#
# <p align="center">
#   <img src="../data/data_schema.png" />
# </p>

# %%
# helper function to populate a sessionData dictionary in the required format
def sessionDataPopulator(session):
  sessionData = []
  for subBlock in session['block']:
      subBlockData = {}
      subBlockData['block'] = subBlock['gameNumber']
      subBlockData['noiseHits'] = subBlock['noiseMetrics']['hits']
      subBlockData['noiseMisses'] = subBlock['noiseMetrics']['misses']
      subBlockData['passHits'] = subBlock['passMetrics']['hits']
      subBlockData['passMisses'] = subBlock['passMetrics']['misses']
      sessionData.append(subBlockData)
  return sessionData

# %%
mainData = pd.DataFrame(index=range(len(valid_user_ids)), columns=['userID', 'modality', 'trainingData', 'auth1Data', 'auth2Data'])
mainData['userID'] = valid_user_ids

for i, user_id in enumerate(valid_user_ids):
    modality = firebase_data[user_id]['GAMETYPE']
    mainData.loc[i, 'modality'] = modality

    sessions = get_sessions(user_id)
    for session in sessions:
    
        if session['session'] == "TRAIN":
            trainingData = sessionDataPopulator(session)
            mainData.at[i, 'trainingData'] = trainingData

        elif session['session'] == "AUTH1":
            auth1Data = sessionDataPopulator(session)
            mainData.at[i, 'auth1Data'] = auth1Data
        
        elif session['session'] == "AUTH2":
            auth2Data = sessionDataPopulator(session)
            mainData.at[i, 'auth2Data'] = auth2Data

# %%
mainData.to_csv('../data/main_NC_Data.csv', index=False)

# %% [markdown]
# #### How to read the CSV

# %%
mainData = pd.read_csv('../data/main_NC_Data.csv')
mainData
# Out:
#                           userID modality  \
# 0   267spXKQrOQxNGhW9Mj19RVBZnF3      AUD
# 1   2IuHuexDUpgOdXCBYfDqO7ubtEC2      AUD
# 2   3YKJchZqXXPUm7ouoYwzWlTp4D53  CONTROL
# 3   4SQKvEIUBucwuWNoKkOVBX30H1P2  CONTROL
# 4   5NToitXbnhXNNLn80hbxLBUSbfw2      VIS
# ..                           ...      ...
# 65  uEJUpBKufKO3DmepKtVcTfFT6WU2      VIS
# 66  umG8DQRaeVd6RPOJfoLKNdclG8e2  CONTROL
# 67  wFRIlVm6H0N0WjSBNg3EMMaTf0H3  CONTROL
# 68  xTyF5REL0bUIT99Hkx2YCWC75572      AUD
# 69  y00ZoK3RqXad5jH5FESwAXkd0Ki1      VIS
#
#                                          trainingData  \
# 0   [{'block': 1, 'noiseHits': 67, 'noiseMisses': ...
# 1   [{'block': 1, 'noiseHits': 47, 'noiseMisses': ...
# 2   [{'block': 1, 'noiseHits': 58, 'noiseMisses': ...
# 3   [{'block': 1, 'noiseHits': 65, 'noiseMisses': ...
# 4   [{'block': 1, 'noiseHits': 66, 'noiseMisses': ...
# ..                                                ...
# 65  [{'block': 1, 'noiseHits': 74, 'noiseMisses': ...
# 66  [{'block': 1, 'noiseHits': 66, 'noiseMisses': ...
# 67  [{'block': 1, 'noiseHits': 61, 'noiseMisses': ...
# 68  [{'block': 1, 'noiseHits': 59, 'noiseMisses': ...
# 69  [{'block': 1, 'noiseHits': 64, 'noiseMisses': ...
#
#                                             auth1Data  \
# 0   [{'block': 1, 'noiseHits': 233, 'noiseMisses':...
# 1   [{'block': 1, 'noiseHits': 211, 'noiseMisses':...
# 2   [{'block': 1, 'noiseHits': 266, 'noiseMisses':...
# 3   [{'block': 1, 'noiseHits': 258, 'noiseMisses':...
# 4   [{'block': 1, 'noiseHits': 250, 'noiseMisses':...
# ..                                                ...
# 65  [{'block': 1, 'noiseHits': 268, 'noiseMisses':...
# 66  [{'block': 1, 'noiseHits': 245, 'noiseMisses':...
# 67  [{'block': 1, 'noiseHits': 251, 'noiseMisses':...
# 68  [{'block': 1, 'noiseHits': 267, 'noiseMisses':...
# 69  [{'block': 1, 'noiseHits': 287, 'noiseMisses':...
#
#                                             auth2Data
# 0   [{'block': 1, 'noiseHits': 248, 'noiseMisses':...
# 1   [{'block': 1, 'noiseHits': 240, 'noiseMisses':...
# 2   [{'block': 1, 'noiseHits': 244, 'noiseMisses':...
# 3   [{'block': 1, 'noiseHits': 252, 'noiseMisses':...
# 4   [{'block': 1, 'noiseHits': 258, 'noiseMisses':...
# ..                                                ...
# 65  [{'block': 1, 'noiseHits': 175, 'noiseMisses':...
# 66  [{'block': 1, 'noiseHits': 242, 'noiseMisses':...
# 67  [{'block': 1, 'noiseHits': 275, 'noiseMisses':...
# 68  [{'block': 1, 'noiseHits': 259, 'noiseMisses':...
# 69  [{'block': 1, 'noiseHits': 266, 'noiseMisses':...
#
# [70 rows x 5 columns]

# %%
mainData['auth1Data'][0]
# Out:
# "[{'subBlock': 1, 'noiseHits': 233, 'noiseMisses': 127, 'passHits': 141, 'passMisses': 39}]"
